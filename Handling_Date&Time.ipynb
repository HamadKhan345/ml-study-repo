# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('/content/orders.csv')
time = pd.read_csv('/content/messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
date['date_year'] = date['date'].dt.year # Extract Year No.
date['date_month'] = date['date'].dt.month # Extract Month No.
date['date_month_name'] = date['date'].dt.month_name() # Extract Month Name
date['date_day'] = date['date'].dt.day # Extract Day No.
date['date_day_name'] = date['date'].dt.day_name() # Extract Day Name
date['date_dow'] = date['date'].dt.dayofweek # Extract Day of Week No.
date['date_quarter'] = date['date'].dt.quarter # Extract Quarter No.

# %%
date.head(2)
# Out:
#         date  product_id  city_id  orders  date_year  date_month  \
# 0 2019-12-10        5628       25       3       2019          12
# 1 2018-08-15        3646       14     157       2018           8
#
#   date_month_name  date_day date_day_name  date_dow  date_quarter
# 0        December        10       Tuesday         1             4
# 1          August        15     Wednesday         2             3

# %%
import datetime

today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2025, 2, 7, 9, 50, 3, 433499)

# %%
today - date['date']
# Out:
# 0     1886 days 09:50:03.433499
# 1     2368 days 09:50:03.433499
# 2     2299 days 09:50:03.433499
# 3     2001 days 09:50:03.433499
# 4     2224 days 09:50:03.433499
#                  ...
# 995   2314 days 09:50:03.433499
# 996   2255 days 09:50:03.433499
# 997   2103 days 09:50:03.433499
# 998   2168 days 09:50:03.433499
# 999   1942 days 09:50:03.433499
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# TIme

time['date'] = pd.to_datetime(time['date'])

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

# %%
time.head(2)
# Out:
#                  date                                               msg  hour  \
# 0 2013-12-15 00:50:00                          ищу на сегодня мужика 37     0
# 1 2014-04-29 23:40:00  ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826    23
#
#    min  sec
# 0   50    0
# 1   40    0

# %%
today - time['date']
# Out:
# 0     4072 days 09:00:03.433499
# 1     3936 days 10:10:03.433499
# 2     4422 days 09:29:03.433499
# 3     3724 days 09:19:03.433499
# 4     4121 days 10:39:03.433499
#                  ...
# 995   4711 days 09:00:03.433499
# 996   4032 days 10:36:03.433499
# 997   4497 days 10:13:03.433499
# 998   4613 days 10:16:03.433499
# 999   3885 days 10:25:03.433499
# Name: date, Length: 1000, dtype: timedelta64[ns]
