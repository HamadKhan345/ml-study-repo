# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

from sklearn.experimental import enable_iterative_imputer  # Required to use IterativeImputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/train.csv')[['Age','Pclass','Fare','Survived']]
df.head()
# Out:
#     Age  Pclass     Fare  Survived
# 0  22.0       3   7.2500         0
# 1  38.0       1  71.2833         1
# 2  26.0       3   7.9250         1
# 3  35.0       1  53.1000         1
# 4  35.0       3   8.0500         0

# %%
df.isnull().sum()
# Out:
# Age         177
# Pclass        0
# Fare          0
# Survived      0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Survived', axis=1), df['Survived'], test_size=0.2, random_state=2)

# %%
X_train
# Out:
#       Age  Pclass      Fare
# 30   40.0       1   27.7208
# 10    4.0       3   16.7000
# 873  47.0       3    9.0000
# 182   9.0       3   31.3875
# 876  20.0       3    9.8458
# ..    ...     ...       ...
# 534  30.0       3    8.6625
# 584   NaN       3    8.7125
# 493  71.0       1   49.5042
# 527   NaN       1  221.7792
# 168   NaN       1   25.9250
#
# [712 rows x 3 columns]

# %%
imputer = IterativeImputer(max_iter=100, random_state=2)
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
clf = LinearRegression()
clf.fit(X_train_imputed, y_train)

predictions = clf.predict(X_test_imputed)

accuracy = accuracy_score(y_test, predictions.round())
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7039106145251397

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Survived', axis=1), df['Survived'], test_size=0.2, random_state=2)

# %%
imputer2 = SimpleImputer(strategy='median')
X_train_imputed2 = imputer2.fit_transform(X_train)
X_test_imputed2 = imputer2.transform(X_test)

# %%
clf2 = LinearRegression()
clf2.fit(X_train_imputed2, y_train)

predictions2 = clf2.predict(X_test_imputed2)

accuracy2 = accuracy_score(y_test, predictions2.round())
print(f"Accuracy: {accuracy2}")
# Out:
# Accuracy: 0.6871508379888268
